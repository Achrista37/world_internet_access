# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np
import random
from scipy.stats import linregress

# %%
# Study data files
worldinternet_path = "internet_users.csv"

# %%
worldinternet_results = pd.read_csv(worldinternet_path)

# %%
worldinternet_results.shape
# Out:
# (215, 6)

# %%
worldinternet_results.head()
# Out:
#   Country or Area Internet Users     Population  Rank Percentage Rank.1
# 0           China    765,367,947  1,409,517,397     1     54.30%    116
# 1           India    461,347,554  1,339,180,127     2     34.45%    145
# 2   United States    244,090,854    324,459,463     3     75.23%     68
# 3          Brazil    141,206,801    209,288,278     4     67.47%     83
# 4           Japan    115,845,120    127,484,450     5     90.87%     23

# %%
# Study data files
worldbank_path = "world_bank.csv"

# %%
worldbank_results = pd.read_csv(worldbank_path)

# %%
worldbank_results.shape
# Out:
# (265, 6)

# %%
worldbank_results.head()
# Out:
#        Economy Code                     Region         Income group  \
# 0        Aruba  ABW  Latin America & Caribbean          High income
# 1  Afghanistan  AFG                 South Asia           Low income
# 2       Angola  AGO         Sub-Saharan Africa  Lower middle income
# 3      Albania  ALB      Europe & Central Asia  Upper middle income
# 4      Andorra  AND      Europe & Central Asia          High income
#
#   Lending category Other (EMU or HIPC)
# 0              NaN                 NaN
# 1              IDA                HIPC
# 2             IBRD                 NaN
# 3             IBRD                 NaN
# 4              NaN                 NaN

# %%
world_overview = pd.merge(worldinternet_results, worldbank_results, left_on='Country or Area', right_on='Economy', how='inner')

# %%
world_overview
# Out:
#             Country or Area Internet Users     Population  Rank  \
# 0                     China    765,367,947  1,409,517,397     1
# 1                     India    461,347,554  1,339,180,127     2
# 2             United States    244,090,854    324,459,463     3
# 3                    Brazil    141,206,801    209,288,278     4
# 4                     Japan    115,845,120    127,484,450     5
# ..                      ...            ...            ...   ...
# 173              San Marino         20,100         33,400   204
# 174                Kiribati         16,971        116,398   205
# 175  British Virgin Islands         14,456         31,196   206
# 176                   Nauru          6,475         11,359   208
# 177                  Tuvalu          5,520         11,192   209
#
#         Percentage Rank.1                 Economy Code  \
# 0           54.30%    116                   China  CHN
# 1           34.45%    145                   India  IND
# ...

# %%
geoJSON_path = "world_bank.csv"
geoJSON_results = pd.read_csv(geoJSON_path)

# %%
geoJSON_results.head()
# Out:
#                                              geojson       featurecla  \
# 0  {"type":"MultiPolygon","coordinates":[[[[180,-...  Admin-0 country
# 1  {"type":"MultiPolygon","coordinates":[[[[33.90...  Admin-0 country
# 2  {"type":"MultiPolygon","coordinates":[[[[-8.66...  Admin-0 country
# 3  {"type":"MultiPolygon","coordinates":[[[[-122....  Admin-0 country
# 4  {"type":"MultiPolygon","coordinates":[[[[-122....  Admin-0 country
#
#    scalerank  LABELRANK                   SOVEREIGNT SOV_A3  ADM0_DIF  LEVEL  \
# 0          1          6                         Fiji    FJI         0      2
# 1          1          3  United Republic of Tanzania    TZA         0      2
# 2          1          7               Western Sahara    SAH         0      2
# 3          1          2                       Canada    CAN         0      2
# 4          1          2     United States of America    US1         1      2
#
#                 TYPE                        ADMIN  ...                NAME_JA  \
# ...

# %%
compilation_df = world_overview = pd.merge(world_overview, geoJSON_results, left_on='Country or Area', right_on='SOVEREIGNT', how='left')

# %%
compilation_df
# Out:
#             Country or Area Internet Users     Population  Rank  \
# 0                     China    765,367,947  1,409,517,397     1
# 1                     India    461,347,554  1,339,180,127     2
# 2             United States    244,090,854    324,459,463     3
# 3                    Brazil    141,206,801    209,288,278     4
# 4                     Japan    115,845,120    127,484,450     5
# ..                      ...            ...            ...   ...
# 178              San Marino         20,100         33,400   204
# 179                Kiribati         16,971        116,398   205
# 180  British Virgin Islands         14,456         31,196   206
# 181                   Nauru          6,475         11,359   208
# 182                  Tuvalu          5,520         11,192   209
#
#         Percentage Rank.1                 Economy Code  \
# 0           54.30%    116                   China  CHN
# 1           34.45%    145                   India  IND
# ...
